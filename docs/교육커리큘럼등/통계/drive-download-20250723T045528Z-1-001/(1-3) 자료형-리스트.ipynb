# %% [markdown]
# **1.1 리스트의 코드 표현**

# %%
a = [10, 20, 30, 40, 50, 60]
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
b = ["Fortune", "favors", "the", "brave"]
print(b)
# Out:
# ['Fortune', 'favors', 'the', 'brave']

# %%
c = [10, 20, "Fortune", "favors"]
print(c)
# Out:
# [10, 20, 'Fortune', 'favors']

# %%
d = [10, 20, ["Fortune", "favors", ["the", "brave"]]]
print(d)
# Out:
# [10, 20, ['Fortune', 'favors', ['the', 'brave']]]

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# **1.2 인덱싱의 코드 표현**

# %%
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
print(a[5])
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
print(a[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-7-1929366416.py in <cell line: 0>()
# ----> 1 print(a[6])
#
# IndexError: list index out of range

# %%
print(d[2])
# Out:
# ['Fortune', 'favors', ['the', 'brave']]

# %%
print(d[2][1])
# Out:
# favors

# %%
print(d[2][2])
# Out:
# ['the', 'brave']

# %%
print(d[2][2][1])
# Out:
# brave

# %%
print(a[-1])
print(a[-2])
print(a[-3])
print(a[-4])
# Out:
# 60
# 50
# 40
# 30

# %% [markdown]
# **1.3 슬라이싱의 코드 표현**

# %%
print(a[0:2])
# Out:
# [10, 20]

# %%
print(a[1:])
# Out:
# [20, 30, 40, 50, 60]

# %%
print(a[:3])
# Out:
# [10, 20, 30]

# %%
print(a[:])
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(a[:-1])
# Out:
# [10, 20, 30, 40, 50]

# %%
print(a[::2])
# Out:
# [10, 30, 50]

# %%
print(a[1:-1:3])
# Out:
# [20, 50]

# %% [markdown]
# **1.4 리스트의 응용 코드 표현**

# %%
# append method

a.append(70)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
# 리스트의 연산

a = [10, 20, 30]
b = [40, 50, 60]
a + b
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
b * 2
# Out:
# [40, 50, 60, 40, 50, 60]

# %%
b + 70
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-23-243838375.py in <cell line: 0>()
# ----> 1 b + 70
#
# TypeError: can only concatenate list (not "int") to list

# %%
b + [70]
# Out:
# [40, 50, 60, 70]

# %%
b + "Fortune"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-25-2210260946.py in <cell line: 0>()
# ----> 1 b + "Fortune"
#
# TypeError: can only concatenate list (not "str") to list

# %%
# 리스트 값 치환

a[0] = 0
print(a)
# Out:
# [0, 20, 30]

# %%
b = [40, [50, 60]]
print(b)
# Out:
# [40, [50, 60]]

# %%
b[1][0] = 100
print(b)
# Out:
# [40, [100, 60]]

# %%
# 리스트 함수

a = [10, 20, 30, 40, 50, 60]
len(a)
# Out:
# 6

# %%
sum(a)
# Out:
# 210

# %%
max(a)
# Out:
# 60

# %%
min(a)
# Out:
# 10

# %%
b = ["Fortune", "favors", "the", "brave"]
'brave' in b
# Out:
# True

# %%
a = [10, 20, 30, 40, 50, 60]
a.insert(3, 35)
print(a)
# Out:
# [10, 20, 30, 35, 40, 50, 60]

# %%
a.remove(35)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a.pop(2)
print(a)
# Out:
# [10, 20, 40, 50, 60]

# %%
e = [1, 2, 2, 2, 3, 4]

e.count(2)
# Out:
# 3

# %%
e = [1, 2, 2, 2, 3, 4]

e.index(3)
# Out:
# 4

# %%
e.index(2)
# Out:
# 1

# %%
f = [1,5, 4, 2, 0]

f.sort()
print(f)
# Out:
# [0, 1, 2, 4, 5]

# %%
b = ["Fortune", "favors", "the", "brave"]

print(" ".join(b))
# Out:
# Fortune favors the brave

# %%
print("-".join(b))
# Out:
# Fortune-favors-the-brave

# %%
g = 'No pain No gain'

g.split()
# Out:
# ['No', 'pain', 'No', 'gain']
